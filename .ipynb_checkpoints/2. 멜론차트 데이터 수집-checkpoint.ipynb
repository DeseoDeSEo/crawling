# %%
import requests as req
from bs4 import BeautifulSoup as bs

# %%
head = {'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/116.0.0.0 Safari/537.36'}

# %%
# 1. req를 통해서 멜론차트 정보를 요청

res1 = req.get("https://www.melon.com/chart/index.htm", headers = head)
res1
# Out:
# <Response [200]>

# %%
# 2. bs을 통해서 html데이터로 변형
soup = bs(res1.text, "lxml")

# %%
# 3. 노래제목 수집
song = soup.select("#lst50 > td:nth-child(6) > div > div > div.ellipsis.rank01 > span > a")
# 강사님 답 : ("div.ellipsis.rank01> span > a")
# 클래스 값 중간에 공백 有 -> 클래스가 복수개 이다.
# 공백을 지우고 반드시 온점.으로 이어준다.
for i in song:
    print(i.text)
# Out:
# Seven (feat. Latto) - Clean Ver.
# Super Shy
# ETA
# 헤어지자 말해요
# 퀸카 (Queencard)
# I AM
# 사막에서 꽃을 피우듯
# Steal The Show (From “엘리멘탈”)
# Fast Forward
# 모래 알갱이
# Spicy
# 사랑은 늘 도망가
# New Jeans
# 이브, 프시케 그리고 푸른 수염의 아내
# Hype boy
# Still With You
# 우리들의 블루스
# Kitsch
# 다시 만날 수 있을까
# UNFORGIVEN (feat. Nile Rodgers)
# Ditto
# 무지개
# Summer (Feat. BE’O (비오))
# 이제 나만 믿어요
# London Boy
# 아버지
# Polaroid
# Love Lee
# 인생찬가
# Attention
# 손오공
# Cool With You
# OMG
# A bientot
# Dynamite
# 손이 참 곱던 그대
# 사랑해 진짜
# 연애편지
# 사건의 지평선
# After LIKE
# CAKE
# I Don't Think That I Like Her
# LOVE DIVE
# 꽃
# 보금자리
# Take Two
# Love Me Again
# Bubble
# 파이팅 해야지 (Feat. 이영지)
# 봄날

# %%
# 4. 가수 이름 수집
singer = soup.select("div.ellipsis.rank02>span.checkEllipsis")

# %%
# 데이터의 개수가 정해진 경우에는
#  반드시 데이터 검증이 필요하다.( 데이터의 길이, 데이터의 중복여부를 확인해야한다.)
len(singer)
# Out:
# 100

# %%
for i in song:
    print(i.text)
# Out:
# Seven (feat. Latto) - Clean Ver.
# Super Shy
# ETA
# 헤어지자 말해요
# 퀸카 (Queencard)
# I AM
# 모래 알갱이
# 사막에서 꽃을 피우듯
# Steal The Show (From “엘리멘탈”)
# 사랑은 늘 도망가
# Fast Forward
# Spicy
# 우리들의 블루스
# 이브, 프시케 그리고 푸른 수염의 아내
# New Jeans
# Hype boy
# 다시 만날 수 있을까
# Still With You
# 무지개
# 이제 나만 믿어요
# London Boy
# 아버지
# Kitsch
# Polaroid
# Ditto
# UNFORGIVEN (feat. Nile Rodgers)
# 인생찬가
# A bientot
# 손이 참 곱던 그대
# 사랑해 진짜
# Summer (Feat. BE’O (비오))
# 연애편지
# Love Lee
# Dynamite
# Attention
# 손오공
# OMG
# Cool With You
# 보금자리
# Take Two
# After LIKE
# 사건의 지평선
# Love Me Again
# I Don't Think That I Like Her
# LOVE DIVE
# 꽃
# CAKE
# 봄날
# 파이팅 해야지 (Feat. 이영지)
# Bubble

# %%
# 5. 수집된 데이터를 텍스트 정보만 추출해서 저장
song_list=[]
singer_list =[]
for i in range(len(song)):
    song_list.append(song[i].text)
    singer_list.append(singer[i].text)

# %%
song_list
singer_list
# Out:
# ['정국',
#  'NewJeans',
#  'NewJeans',
#  '박재정',
#  '(여자)아이들',
#  'IVE (아이브)',
#  '임영웅',
#  '우디 (Woody)',
#  'Lauv',
#  '임영웅',
#  '전소미',
#  'aespa',
#  '임영웅',
#  'LE SSERAFIM (르세라핌)',
#  'NewJeans',
#  'NewJeans',
#  '임영웅',
#  '정국',
#  '임영웅',
#  '임영웅',
#  '임영웅',
#  '임영웅',
#  'IVE (아이브)',
#  '임영웅',
#  'NewJeans',
#  'LE SSERAFIM (르세라핌)',
#  '임영웅',
#  '임영웅',
#  '임영웅',
#  '임영웅',
#  'Paul Blanco',
#  '임영웅',
#  'AKMU (악뮤)',
#  '방탄소년단',
#  'NewJeans',
#  '세븐틴 (SEVENTEEN)',
#  'NewJeans',
#  'NewJeans',
#  '임영웅',
#  '방탄소년단',
#  'IVE (아이브)',
#  '윤하 (YOUNHA)',
#  'V',
#  'Charlie Puth',
#  'IVE (아이브)',
#  '지수 (JISOO)',
#  'ITZY (있지)',
#  '방탄소년단',
#  '부석순 (SEVENTEEN)',
#  'STAYC(스테이씨)']

# %%
# 6. 표를 제작.
import pandas as pd

# %%
dic = {"가수이름":singer_list, "노래제목":song_list}
melon = pd.DataFrame(dic)
melon
# Out:
#                   가수이름                              노래제목
# 0                   정국  Seven (feat. Latto) - Clean Ver.
# 1             NewJeans                         Super Shy
# 2             NewJeans                               ETA
# 3                  박재정                          헤어지자 말해요
# 4              (여자)아이들                    퀸카 (Queencard)
# 5            IVE (아이브)                              I AM
# 6                  임영웅                            모래 알갱이
# 7           우디 (Woody)                       사막에서 꽃을 피우듯
# 8                 Lauv      Steal The Show (From “엘리멘탈”)
# 9                  임영웅                         사랑은 늘 도망가
# 10                 전소미                      Fast Forward
# 11               aespa                             Spicy
# 12                 임영웅                          우리들의 블루스
# 13  LE SSERAFIM (르세라핌)             이브, 프시케 그리고 푸른 수염의 아내
# 14            NewJeans                         New Jeans
# 15            NewJeans                          Hype boy
# 16                 임영웅                       다시 만날 수 있을까
# 17                  정국                    Still With You
# 18                 임영웅                               무지개
# 19                 임영웅                         이제 나만 믿어요
# 20                 임영웅                        London Boy
# 21                 임영웅                               아버지
# 22           IVE (아이브)                            Kitsch
# 23                 임영웅                          Polaroid
# 24            NewJeans                             Ditto
# 25  LE SSERAFIM (르세라핌)   UNFORGIVEN (feat. Nile Rodgers)
# 26                 임영웅                              인생찬가
# 27                 임영웅                         A bientot
# 28                 임영웅                        손이 참 곱던 그대
# 29                 임영웅                            사랑해 진짜
# 30         Paul Blanco          Summer (Feat. BE’O (비오))
# 31                 임영웅                              연애편지
# 32           AKMU (악뮤)                          Love Lee
# 33               방탄소년단                          Dynamite
# 34            NewJeans                         Attention
# 35     세븐틴 (SEVENTEEN)                               손오공
# 36            NewJeans                               OMG
# 37            NewJeans                     Cool With You
# 38                 임영웅                              보금자리
# 39               방탄소년단                          Take Two
# 40           IVE (아이브)                        After LIKE
# 41         윤하 (YOUNHA)                           사건의 지평선
# 42                   V                     Love Me Again
# 43        Charlie Puth     I Don't Think That I Like Her
# 44           IVE (아이브)                         LOVE DIVE
# 45          지수 (JISOO)                                 꽃
# 46           ITZY (있지)                              CAKE
# 47               방탄소년단                                봄날
# 48     부석순 (SEVENTEEN)               파이팅 해야지 (Feat. 이영지)
# 49         STAYC(스테이씨)                            Bubble

# %%
# 7. 파일로 제작.
# 인코딩 작업
# 한글이 깨지지 않게 반드시 해줘야한다.
# 1. utf-8 
# 2. euc-kr
# 3. utf-8-sig
melon.to_csv("멜론차트.csv", encoding="euc-kr")
